# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls
# Out:
#  INSTALL.md*                     docker/
#  R-50.pkl*                       docs/
#  README.md*                      figure/
#  TrainDoNet.ipynb*               isbi/
# '[Success]Setup DoNet2.ipynb'*   metrics.json*
#  build/                          old_detectron2.egg-info/
#  build_done/                     output/
#  configs/                        projects/
#  customized_tools/               pycoco/
#  detectron2/                     setup.cfg*
#  detectron2.egg-info/            setup.py*
#  dev/                            src_detectron2.egg-info/
#  dist/                           tools/

# %%
import torch
print(torch.__version__)
# Out:
# 2.4.0+cu121

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ------------------
# absl-py                   2.1.0
# aiohappyeyeballs          2.3.6
# aiohttp                   3.10.3
# aiosignal                 1.3.1
# annotated-types           0.7.0
# anyio                     4.4.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# async-timeout             4.0.3
# attrs                     24.2.0
# autocommand               2.2.2
# babel                     2.16.0
# backoff                   2.2.1
# backports.tarfile         1.2.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# boto3                     1.34.162
# botocore                  1.34.162
# cachetools                5.4.0
# certifi                   2024.7.4
# cffi                      1.17.0
# charset-normalizer        3.3.2
# click                     8.1.7
# ...

# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !rm -rf /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages/numpy*

# %%
# !pip install numpy==1.23.0

# %%
# !pip install Pillow==9.1.0

# %%
# !python setup.py build
# Out:
# running build
# running build_py
# running build_ext
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no g++ version bounds defined for CUDA version 12.1
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'detectron2._C' extension
# Emitting ninja build file /teamspace/studios/this_studio/DoNetProject/DoNet/build/temp.linux-x86_64-cpython-310/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ...

# %%
# !python setup.py install
# Out:
# running install
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet

# %%
# %ls
# Out:
#  INSTALL.md*                     docs/
#  R-50.pkl*                       figure/
#  README.md*                      isbi/
#  TrainDoNet.ipynb*               metrics.json*
# '[Success]Setup DoNet2.ipynb'*   old_detectron2.egg-info/
#  build/                          output/
#  build_done/                     output2/
#  configs/                        projects/
#  customized_tools/               pycoco/
#  detectron2/                     setup.cfg*
#  detectron2.egg-info/            setup.py*
#  dev/                            src_detectron2.egg-info/
#  dist/                           tools/
#  docker/

# %%
# %pip list

# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python customized_tools/train.py \
    --annTrainFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_train.json \
    --imgTrainFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_train \
    --annValFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_val.json \
    --imgValFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_val \
    --configFile COCO-InstanceSegmentation/mask_triple_branch_rcnn_R_50_FPN_3x_DRM_CRM_MRP.yaml \
    --outputDir /teamspace/studios/this_studio/DoNetProject/DoNet/output/
# Out:
# CUDNN_BENCHMARK: False
# DATALOADER:
#   ASPECT_RATIO_GROUPING: True
#   FILTER_EMPTY_ANNOTATIONS: True
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: ()
#   PROPOSAL_FILES_TRAIN: ()
#   TEST: ('amodal_coco_val',)
#   TRAIN: ('amodal_coco_train',)
# GLOBAL:
#   HACK: 1.0
# INPUT:
#   CROP:
#     ENABLED: False
#     SIZE: [0.9, 0.9]
#     TYPE: relative_range
#   FORMAT: BGR
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN: (640, 672, 704, 736, 768, 800)
#   MIN_SIZE_TRAIN_SAMPLING: choice
# MODEL:
#   ANCHOR_GENERATOR:
#     ANGLES: [[-90, 0, 90]]
#     ASPECT_RATIOS: [[0.5, 1.0, 2.0]]
#     NAME: DefaultAnchorGenerator
#     OFFSET: 0.0
#     SIZES: [[32], [64], [128], [256], [512]]
#   BACKBONE:
#     FREEZE_AT: 2
#     NAME: build_resnet_fpn_backbone
# ...

# %% [markdown]
# Train2

# %%
# !python customized_tools/train.py \
    --annTrainFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_train.json \
    --imgTrainFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_train \
    --annValFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_val.json \
    --imgValFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_val \
    --configFile COCO-InstanceSegmentation/mask_triple_branch_rcnn_R_50_FPN_3x_DRM_CRM.yaml \
    --outputDir /teamspace/studios/this_studio/DoNetProject/DoNet/output2/
# Out:
# CUDNN_BENCHMARK: False
# DATALOADER:
#   ASPECT_RATIO_GROUPING: True
#   FILTER_EMPTY_ANNOTATIONS: True
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: ()
#   PROPOSAL_FILES_TRAIN: ()
#   TEST: ('amodal_coco_val',)
#   TRAIN: ('amodal_coco_train',)
# GLOBAL:
#   HACK: 1.0
# INPUT:
#   CROP:
#     ENABLED: False
#     SIZE: [0.9, 0.9]
#     TYPE: relative_range
#   FORMAT: BGR
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN: (640, 672, 704, 736, 768, 800)
#   MIN_SIZE_TRAIN_SAMPLING: choice
# MODEL:
#   ANCHOR_GENERATOR:
#     ANGLES: [[-90, 0, 90]]
#     ASPECT_RATIOS: [[0.5, 1.0, 2.0]]
#     NAME: DefaultAnchorGenerator
#     OFFSET: 0.0
#     SIZES: [[32], [64], [128], [256], [512]]
#   BACKBONE:
#     FREEZE_AT: 2
#     NAME: build_resnet_fpn_backbone
# ...

# %%
# Look at training curves in tensorboard:
# %load_ext tensorboard
# %tensorboard --logdir output

# %%
# !pip show Pillow
# Out:
# Name: Pillow
# Version: 9.1.0
# Summary: Python Imaging Library (Fork)
# Home-page: https://python-pillow.org
# Author: Alex Clark (PIL Fork Author)
# Author-email: aclark@python-pillow.org
# License: HPND
# Location: /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages
# Requires:
# Required-by: detectron2, fvcore, matplotlib, torchvision

# %%
# !pip install Pillow==8.0.0

# %%
# !pip install --upgrade Pillow

# %% [markdown]
# Train3

# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install tensorboard

# %%
# !pip show tensorboard
# Out:
# Name: tensorboard
# Version: 2.15.1
# Summary: TensorBoard lets you watch Tensors Flow
# Home-page: https://github.com/tensorflow/tensorboard
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages
# Requires: absl-py, google-auth, google-auth-oauthlib, grpcio, markdown, numpy, protobuf, requests, setuptools, six, tensorboard-data-server, werkzeug
# Required-by: detectron2

# %%
# !tensorboard --logdir /teamspace/studios/this_studio/DoNetProject/DoNet/output3/
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.15.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls
# Out:
#  INSTALL.md*                     docs/
#  R-50.pkl*                       figure/
#  README.md*                      isbi/
#  TrainDoNet.ipynb*               metrics.json*
# '[Success]Setup DoNet2.ipynb'*   old_detectron2.egg-info/
#  build/                          output/
#  build_done/                     output2/
#  configs/                        output3/
#  customized_tools/               projects/
#  detectron2/                     pycoco/
#  detectron2.egg-info/            setup.cfg*
#  dev/                            setup.py*
#  dist/                           src_detectron2.egg-info/
#  docker/                         tools/

# %%
# !python customized_tools/train.py \
    --annTrainFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_train.json \
    --imgTrainFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_train \
    --annValFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_val.json \
    --imgValFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_val \
    --configFile COCO-InstanceSegmentation/mask_triple_branch_rcnn_R_50_FPN_3x_DRM_CRM_MRP.yaml \
    --outputDir /teamspace/studios/this_studio/DoNetProject/DoNet/output3/
# Out:
# CUDNN_BENCHMARK: False
# DATALOADER:
#   ASPECT_RATIO_GROUPING: True
#   FILTER_EMPTY_ANNOTATIONS: True
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: ()
#   PROPOSAL_FILES_TRAIN: ()
#   TEST: ('amodal_coco_val',)
#   TRAIN: ('amodal_coco_train',)
# GLOBAL:
#   HACK: 1.0
# INPUT:
#   CROP:
#     ENABLED: False
#     SIZE: [0.9, 0.9]
#     TYPE: relative_range
#   FORMAT: BGR
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN: (640, 672, 704, 736, 768, 800)
#   MIN_SIZE_TRAIN_SAMPLING: choice
# MODEL:
#   ANCHOR_GENERATOR:
#     ANGLES: [[-90, 0, 90]]
#     ASPECT_RATIOS: [[0.5, 1.0, 2.0]]
#     NAME: DefaultAnchorGenerator
#     OFFSET: 0.0
#     SIZES: [[32], [64], [128], [256], [512]]
#   BACKBONE:
#     FREEZE_AT: 2
#     NAME: build_resnet_fpn_backbone
# ...

# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls
# Out:
#  INSTALL.md*                     docs/
#  R-50.pkl*                       figure/
#  README.md*                      isbi/
#  TrainDoNet.ipynb*               metrics.json*
# '[Success]Setup DoNet2.ipynb'*   old_detectron2.egg-info/
#  build/                          output/
#  build_done/                     output2/
#  configs/                        output3/
#  customized_tools/               projects/
#  detectron2/                     pycoco/
#  detectron2.egg-info/            setup.cfg*
#  dev/                            setup.py*
#  dist/                           src_detectron2.egg-info/
#  docker/                         tools/

# %%
# !python customized_tools/evaluate.py \
    --annTestFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_test.json \
    --imgTestFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_test/ \
    --outputDir /teamspace/studios/this_studio/DoNetProject/output_evaluate_25k/\
    --weightsFile /teamspace/studios/this_studio/DoNetProject/DoNet/output3/model_0024999.pth \
    --configFile COCO-InstanceSegmentation/mask_triple_branch_rcnn_R_50_FPN_3x_DRM_CRM_MRP.yaml
# Out:
# outputDir: /teamspace/studios/this_studio/DoNetProject/results25k/
#
#  annTestFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_test.json
#
#  imgTestFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_test/
#
#  cfg value
#  CUDNN_BENCHMARK: False
# DATALOADER:
#   ASPECT_RATIO_GROUPING: True
#   FILTER_EMPTY_ANNOTATIONS: True
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: ()
#   PROPOSAL_FILES_TRAIN: ()
#   TEST: ('amodal_coco_test',)
#   TRAIN: ('amodal_coco_test',)
# GLOBAL:
#   HACK: 1.0
# INPUT:
#   CROP:
#     ENABLED: False
#     SIZE: [0.9, 0.9]
#     TYPE: relative_range
#   FORMAT: BGR
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN: (640, 672, 704, 736, 768, 800)
#   MIN_SIZE_TRAIN_SAMPLING: choice
# MODEL:
# ...

# %%
# %cd /teamspace/studios/this_studio/DoNetProject/DoNet/
# Out:
# /teamspace/studios/this_studio/DoNetProject/DoNet
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python customized_tools/inference.py \
    --annTestFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/annotations/isbi_test.json \
    --imgTestFile /teamspace/studios/this_studio/DoNetProject/DoNet/isbi/isbi_test/ \
    --outputDir /teamspace/studios/this_studio/DoNetProject/results25k/\
    --weightsFile /teamspace/studios/this_studio/DoNetProject/DoNet/output3/model_0024999.pth \
    --configFile COCO-InstanceSegmentation/mask_triple_branch_rcnn_R_50_FPN_3x_DRM_CRM_MRP.yaml
# Out:
# Traceback (most recent call last):
#   File "/teamspace/studios/this_studio/DoNetProject/DoNet/customized_tools/inference.py", line 50, in <module>
#     predictor = DefaultPredictor(cfg)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/detectron2-0.1.2-py3.10-linux-x86_64.egg/detectron2/engine/defaults.py", line 162, in __init__
#     self.model = build_model(self.cfg)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/detectron2-0.1.2-py3.10-linux-x86_64.egg/detectron2/modeling/meta_arch/build.py", line 19, in build_model
#     return META_ARCH_REGISTRY.get(meta_arch)(cfg)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/detectron2-0.1.2-py3.10-linux-x86_64.egg/detectron2/modeling/meta_arch/rcnn.py", line 66, in __init__
#     pixel_mean = torch.Tensor(cfg.MODEL.PIXEL_MEAN).to(self.device).view(num_channels, 1, 1)
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.4.0+cu121
